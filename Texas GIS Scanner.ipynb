# %%
import os
from selenium import webdriver
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.support import expected_conditions as EC
from selenium.webdriver.support.ui import WebDriverWait
from selenium.webdriver.common.by import By
from selenium.common.exceptions import TimeoutException
import csv
import time
import pyautogui

PATH = '/Users/stefan/Documents/Additional Libraries/Chromedrive/chromedriver'
driver = webdriver.Safari()
driver.get("https://gis.rrc.texas.gov/GISViewer/")
driver.fullscreen_window()
time.sleep(2)
section = [0, 30000]

excel_labels = ['API Number', 'Well_Number', 'Symbol_Desc','Symbol','Reliab','Location_Source','Lat27','Long27','Lat83',
                'Long83','Wellbore_Status','Last_Permit_Issued','Last_Permit_Operator_Number','Last_Permit_Operator',
                'Last_Permit_Lease_Name','Total_Depth','Surface_Location','Abstract','Survey','Block','Section','Distance1',
                'Direction1','Distance2','Direction2','Proration_Schedule','District','LeaseID','Operator_Number',
                'Operator','Lease_Name','Field','Well_No','Well_Type','On_Schedule','plugDate','plugDepth','plugOperator',
                'plugLeasename']

TX_counties = list(range(1,508,2))+list(range(600,607))+list(range(700,716))

def collectData(county,sectioning):
    incorrect = 0
    for i in range(1,99999):
        print(str(county).zfill(3)+str(i+section[sectioning]).zfill(5))
        WebDriverWait(driver, 5).until(EC.element_to_be_clickable((By.ID, 'searchField')))
        driver.find_element_by_id('searchField').clear()
        driver.find_element_by_id('searchField').send_keys(str(county).zfill(3)+str(i+section[sectioning]).zfill(5))
        driver.find_element_by_id('searchField').send_keys(Keys.RETURN)
        time.sleep(0.5)

        if False:
            incorrect = incorrect + 1
            print("Wrong number")
        else:
            WebDriverWait(driver, 20).until(EC.element_to_be_clickable((By.XPATH, '//*[@id="toggleRadiusButton"]/span[1]')))
            driver.find_element_by_xpath('//*[@id="toggleRadiusButton"]/span[1]').click()
            driver.find_element_by_id('radiusText').clear()
            driver.find_element_by_id('radiusText').send_keys('0.03')
            time.sleep(0.3)
            pyautogui.click(x=4440,y=372)
            try:
                #driver.find_element_by_id('queryCSVButtonB_label')
                #WebDriverWait(driver, 5).until(EC._element_if_visible(By.ID, 'queryCSVButtonB_label'))
                time.sleep(2)
                driver.find_element_by_id('queryCSVButtonB_label').click()
            except TimeoutException:
                try:
                    pyautogui.click(x=4440, y=372)
                    WebDriverWait(driver, 5).until(EC.element_to_be_clickable(By.ID, 'queryCSVButtonB_label'))
                    driver.find_element_by_id('queryCSVButtonB_label').click()
                except TimeoutException:
                    pass
                pass
            WebDriverWait(driver, 5).until(EC.element_to_be_clickable((By.XPATH, '//*[@id="radiusCloseBtn"]/a/img')))
            driver.find_element_by_xpath('//*[@id="radiusCloseBtn"]/a/img').click()
            transferData()
        if incorrect > 100:
            break
    print("Finished")
    driver.quit()

def transferData():
    try:
        with open('/Users/stefan/Downloads/RadiusResults.csv') as file:
            reader = csv.reader(file)
            x=0
            for row in reader:
                if x == 0:
                    x=1
                elif x == 1:
                    with open('WellInfo.csv', 'a', newline='') as file:
                        write = csv.writer(file, dialect='excel')
                        write.writerow(row)
            os.remove('/Users/stefan/Downloads/RadiusResults.csv')
    except FileNotFoundError:
        with open('/Users/stefan/Downloads/RadiusResults-1.csv') as file:
            x=0
            reader = csv.reader(file)
            for row in reader:
                if x == 0:
                    x=1
                elif x == 1:
                    with open('WellInfo.csv', 'a', newline='') as file:
                        write = csv.writer(file, dialect='excel')
                        write.writerow(row)
            os.remove('/Users/stefan/Downloads/RadiusResults-1.csv')
            time.sleep(5)

def initializeDoc():
    with open('WellInfo.csv', 'w', newline='') as file:
        write = csv.writer(file, dialect='excel')
        write.writerow(excel_labels)

def generateEntireDataset():
    for i in TX_counties:
        collectData(i, 0)
        collectData(i, 1)
    print("100% Complete")

initializeDoc()
collectData(3, 0)

#This program almost works, but apparently we aren't interested in this information very much
#I am instead going to focus more on the pdf scanning aspect of this and try to get the casing information from there
# Out:
# 00300001
# 00300002
# 00300003
# 00300004
# 00300005
# 00300006
# 00300007
# 00300008
# 00300009
# 00300010
# 00300011
# 00300012
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-10-d783c7b6ae4d> in <module>
#     106
#     107 initializeDoc()
# --> 108 collectData(3, 0)
#     109
#     110 #This program almost works, but apparently we aren't interested in this information very much
#
# <ipython-input-10-d783c7b6ae4d> in collectData(county, sectioning)
#      59                     pass
#      60                 pass
# ---> 61             WebDriverWait(driver, 5).until(EC.element_to_be_clickable((By.XPATH, '//*[@id="radiusCloseBtn"]/a/img')))
#      62             driver.find_element_by_xpath('//*[@id="radiusCloseBtn"]/a/img').click()
#      63             transferData()
#
# ...
